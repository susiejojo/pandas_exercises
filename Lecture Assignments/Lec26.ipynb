# %%
import pandas as pd

# %%
users_col=['user_id','age','gender','occupation','zip-code']

# %%
users=pd.read_table("http://bit.ly/movieusers",sep="|",header=None,names=users_col)
# Out:
# /home/susiejojo/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip-code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.shape
# Out:
# (943, 5)

# %%
users['zip-code'].duplicated().sum() #no of duplicates
# Out:
# 148

# %%
users.duplicated().sum()
# Out:
# 0

# %%
users.loc[users['zip-code'].duplicated(keep="last"),:]
# Out:
#      user_id  age gender     occupation zip-code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 6          7   57      M  administrator    91344
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 22        23   30      F         artist    48197
# 23        24   21      F         artist    94533
# 27        28   32      M         writer    55369
# 28        29   41      M     programmer    94043
# 30        31   24      M         artist    10003
# 31        32   28      F        student    78741
# 36        37   23      M        student    55105
# 39        40   38      M      scientist    27514
# 40        41   33      M       engineer    80525
# 43        44   26      M     technician    46260
# 51        52   18      F        student    55105
# 52        53   26      M     programmer    55414
# 64        65   51      F       educator    48118
# ...

# %%
users.drop_duplicates(keep='first').shape
# Out:
# (943, 5)

# %%
users.drop_duplicates(subset=['zip-code','age']).shape
# Out:
# (927, 5)
