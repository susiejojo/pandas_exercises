# %%
import pandas as pd

# %%
ufo=pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo.Time.str.slice(-5,-3).astype(int).head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int64

# %%
ufo['Time']=pd.to_datetime(ufo.Time)

# %%
ufo.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
ufo['Time'].dt.weekday_name.head()
# Out:
# 0     Sunday
# 1     Monday
# 2     Sunday
# 3     Monday
# 4    Tuesday
# Name: Time, dtype: object

# %%
ts=pd.to_datetime('1/1/2000')

# %%
ufo.loc[ufo['Time']>=ts,:]
# Out:
#                  City Colors Reported Shape Reported State                Time
# 15606     Bakersfield             NaN            NaN    CA 2000-01-01 00:01:00
# 15607   New York City             NaN         SPHERE    NY 2000-01-01 00:01:00
# 15608     Los Angeles             NaN            NaN    CA 2000-01-01 00:03:00
# 15609       San Diego           GREEN          LIGHT    CA 2000-01-01 00:23:00
# 15610         Laporte             NaN          OTHER    TX 2000-01-01 02:13:00
# 15611   Bellefontaine             RED          LIGHT    OH 2000-01-01 03:00:00
# 15612      Nellis AFB             NaN          LIGHT    NV 2000-01-01 03:30:00
# 15613          Clovis             NaN          LIGHT    CA 2000-01-01 05:00:00
# 15614          Gurnee             NaN          LIGHT    IL 2000-01-01 14:45:00
# 15615   San Francisco             NaN          LIGHT    CA 2000-01-01 16:20:00
# 15616         Medford             NaN      FORMATION    OR 2000-01-01 17:00:00
# 15617         Houston             NaN          FLASH    TX 2000-01-01 20:30:00
# 15618          Patoka             NaN       TRIANGLE    IL 2000-01-01 21:00:00
# 15619         Houston           GREEN         SPHERE    TX 2000-01-01 21:35:00
# 15620      Evansville             NaN          CIGAR    IN 2000-01-01 22:00:00
# 15621           Erath             NaN            EGG    LA 2000-01-01 23:00:00
# 15622   Coral Springs             NaN            NaN    FL 2000-01-01 23:30:00
# 15623    Jacksonville             NaN      RECTANGLE    FL 2000-01-02 00:00:00
# 15624            Mesa             NaN           OVAL    AZ 2000-01-02 00:30:00
# 15625        Chandler             NaN        DIAMOND    AZ 2000-01-02 18:30:00
# 15626        Murrieta             NaN       FIREBALL    CA 2000-01-02 19:33:00
# 15627       Kennewick             NaN          LIGHT    WA 2000-01-02 19:34:00
# 15628        Oroville             NaN          LIGHT    CA 2000-01-02 20:00:00
# 15629     Studio City            BLUE      RECTANGLE    CA 2000-01-02 21:00:00
# 15630   Anaheim Hills           GREEN          LIGHT    CA 2000-01-02 21:30:00
# 15631        Redlands           GREEN       FIREBALL    CA 2000-01-02 21:30:00
# 15632        Temecula           GREEN       FIREBALL    CA 2000-01-02 21:30:00
# 15633        Glendale             NaN       FIREBALL    CA 2000-01-02 21:33:00
# 15634   Big Bear Lake            BLUE          OTHER    CA 2000-01-02 21:35:00
# 15635       La Quinta             NaN      FORMATION    CA 2000-01-02 21:35:00
# ...               ...             ...            ...   ...                 ...
# 18211         Holyoke             NaN        DIAMOND    MA 2000-12-28 18:00:00
# 18212          Carson             NaN           DISK    CA 2000-12-28 18:20:00
# 18213        Pasadena           GREEN       FIREBALL    CA 2000-12-28 19:10:00
# 18214          Austin             NaN      FORMATION    TX 2000-12-29 00:00:00
# 18215        El Campo             NaN          OTHER    TX 2000-12-29 09:00:00
# 18216    Garden Grove          ORANGE          LIGHT    CA 2000-12-29 16:10:00
# 18217   Berthoud Pass             NaN       TRIANGLE    CO 2000-12-29 19:30:00
# 18218      Sisterdale             NaN        DIAMOND    TX 2000-12-29 20:00:00
# 18219    Garden Grove             NaN        CHEVRON    CA 2000-12-29 20:30:00
# 18220     Shasta Lake            BLUE           DISK    CA 2000-12-29 20:30:00
# 18221        Franklin             NaN           DISK    NH 2000-12-29 20:50:00
# 18222  Albrightsville             NaN          OTHER    PA 2000-12-29 21:00:00
# 18223      Greenville             NaN            NaN    SC 2000-12-29 22:00:00
# 18224         Eufaula             NaN           DISK    OK 2000-12-29 23:30:00
# 18225     Simi Valley             NaN      FORMATION    CA 2000-12-30 10:00:00
# 18226   San Francisco             NaN      FORMATION    CA 2000-12-30 22:00:00
# 18227   San Francisco             NaN       TRIANGLE    CA 2000-12-30 22:00:00
# 18228      Kingsville             NaN          LIGHT    TX 2000-12-31 04:00:00
# 18229         Chicago             NaN           DISK    IL 2000-12-31 11:45:00
# 18230     Pismo Beach             NaN           OVAL    CA 2000-12-31 20:00:00
# 18231     Pismo Beach             NaN           OVAL    CA 2000-12-31 20:00:00
# 18232            Lodi             NaN            NaN    WI 2000-12-31 20:30:00
# 18233       Anchorage             RED        VARIOUS    AK 2000-12-31 21:00:00
# 18234        Capitola             NaN       TRIANGLE    CA 2000-12-31 22:00:00
# 18235  Fountain Hills             NaN            NaN    AZ 2000-12-31 23:00:00
# 18236      Grant Park             NaN       TRIANGLE    IL 2000-12-31 23:00:00
# 18237     Spirit Lake             NaN           DISK    IA 2000-12-31 23:00:00
# 18238     Eagle River             NaN            NaN    WI 2000-12-31 23:45:00
# 18239     Eagle River             RED          LIGHT    WI 2000-12-31 23:45:00
# 18240            Ybor             NaN           OVAL    FL 2000-12-31 23:59:00
#
# [2635 rows x 5 columns]

# %%
ufo['Time'].max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
ufo['Time'].min()
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
ufo['Time'].max()-ufo['Time'].min()
# Out:
# Timedelta('25781 days 01:59:00')

# %%
# %matplotlib inline

# %%
ufo['Year']=ufo.Time.dt.year

# %%
ufo.Year.value_counts().sort_index().plot()
